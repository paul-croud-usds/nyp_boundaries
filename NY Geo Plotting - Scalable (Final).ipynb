# %%
#dependencies
import pandas as pd #used to bring in zone/zip csv
import geopandas #package to do all geographic analysis/cleaning
import matplotlib.pyplot as plt #used to plot graphs in notebook
from shapely.geometry import MultiPoint, Polygon, Point #used to create certain shapes
import math

# %%
# file with all zip codes to use
file = 'ny_new_york_zip_codes_geo.min.json'

# %%
# import geoJSON file
gdf = geopandas.read_file(file)
gdf
# Out:
#      STATEFP10 ZCTA5CE10  GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  \
# 0           36     12205  3612205        B5   G6350          S   40906445
# 1           36     12009  3612009        B5   G6350          S  135241924
# 2           36     14804  3614804        B5   G6350          S  144718714
# 3           36     14836  3614836        B5   G6350          S   77612958
# 4           36     14536  3614536        B5   G6350          S   47193482
# ...        ...       ...      ...       ...     ...        ...        ...
# 1789        36     10503  3610503        B5   G6350          S      38497
# 1790        36     10535  3610535        B5   G6350          S    1169775
# 1791        36     14569  3614569        B5   G6350          S  197585027
# 1792        36     14478  3614478        B5   G6350          S   30311215
# 1793        36     14415  3614415        B5   G6350          S    3760955
#
#       AWATER10   INTPTLAT10    INTPTLON10 PARTFLG10  \
# 0       243508  +42.7187855  -073.8292399         N
# 1      2168637  +42.6975663  -074.0355422         N
# 2       232123  +42.3172588  -077.8479358         N
# 3       131305  +42.5429182  -077.8781933         N
# 4       425175  +42.5439751  -078.0836709         N
# ...        ...          ...           ...       ...
# 1789         0  +41.0265555  -073.8753095         N
# 1790    154348  +41.3351693  -073.7939193         N
# 1791   1112470  +42.7346931  -078.1685932         N
# 1792         0  +42.5778234  -077.1263221         N
# 1793         0  +42.7554950  -077.0170837         N
#
#                                                geometry
# 0     POLYGON ((-73.87052 42.75123, -73.86861 42.756...
# 1     POLYGON ((-74.10891 42.65300, -74.10889 42.653...
# 2     POLYGON ((-77.92747 42.34775, -77.92632 42.347...
# 3     MULTIPOLYGON (((-77.95599 42.47433, -77.95600 ...
# 4     POLYGON ((-78.05030 42.53850, -78.05024 42.538...
# ...                                                 ...
# 1789  POLYGON ((-73.87383 41.02557, -73.87631 41.025...
# 1790  POLYGON ((-73.81299 41.33241, -73.81285 41.332...
# 1791  POLYGON ((-78.19740 42.82658, -78.19619 42.826...
# 1792  POLYGON ((-77.09451 42.62465, -77.09428 42.624...
# 1793  MULTIPOLYGON (((-77.01503 42.75771, -77.01492 ...
#
# [1794 rows x 12 columns]

# %%
# import file with Zones and Zip Codes to merge to gdf (to summarize by zone)
zip_df = pd.read_csv('nyp_zips.csv')
zip_df['zip'] = zip_df['zip'].astype(str) #convert zips to objext/string as stored in geoJSON/gdf
zip_df
# Out:
#               zone    zip
# 0      East Harlem  10029
# 1      East Harlem  10035
# 2    Gramercy Park  10010
# 3    Gramercy Park  10016
# 4    Gramercy Park  10017
# ..             ...    ...
# 199       Brooklyn  11236
# 200       Brooklyn  11237
# 201       Brooklyn  11238
# 202       Brooklyn  11239
# 203       Brooklyn  11249
#
# [204 rows x 2 columns]

# %%
# add zone column to gdf
gdf = gdf.merge(zip_df, left_on ='ZCTA5CE10', right_on ='zip', how ='left')
gdf.head()
# Out:
#   STATEFP10 ZCTA5CE10  GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  \
# 0        36     12205  3612205        B5   G6350          S   40906445
# 1        36     12009  3612009        B5   G6350          S  135241924
# 2        36     14804  3614804        B5   G6350          S  144718714
# 3        36     14836  3614836        B5   G6350          S   77612958
# 4        36     14536  3614536        B5   G6350          S   47193482
#
#    AWATER10   INTPTLAT10    INTPTLON10 PARTFLG10  \
# 0    243508  +42.7187855  -073.8292399         N
# 1   2168637  +42.6975663  -074.0355422         N
# 2    232123  +42.3172588  -077.8479358         N
# 3    131305  +42.5429182  -077.8781933         N
# 4    425175  +42.5439751  -078.0836709         N
#
#                                             geometry zone  zip
# 0  POLYGON ((-73.87052 42.75123, -73.86861 42.756...  NaN  NaN
# 1  POLYGON ((-74.10891 42.65300, -74.10889 42.653...  NaN  NaN
# 2  POLYGON ((-77.92747 42.34775, -77.92632 42.347...  NaN  NaN
# 3  MULTIPOLYGON (((-77.95599 42.47433, -77.95600 ...  NaN  NaN
# 4  POLYGON ((-78.05030 42.53850, -78.05024 42.538...  NaN  NaN

# %%
# dissolve technique will group zones into a single geometric shape
world = gdf[['zone', 'geometry']]
zones = gdf.dissolve(by='zone')
zones.to_file("zones_file.geojson", driver="GeoJSON")
zones.head()
# Out:
#                                                               geometry  \
# zone
# Brooklyn             POLYGON ((-73.95985 40.57401, -73.96037 40.574...
# Central Harlem       MULTIPOLYGON (((-73.94879 40.79748, -73.94910 ...
# Chelsea and Clinton  POLYGON ((-74.00273 40.74029, -74.00464 40.741...
# East Harlem          MULTIPOLYGON (((-73.92869 40.78118, -73.93149 ...
# Gramercy Park        POLYGON ((-73.98451 40.73696, -73.98445 40.737...
#
#                     STATEFP10 ZCTA5CE10  GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10  \
# zone
# Brooklyn                   36     11234  3611234        B5   G6350          S
# Central Harlem             36     10030  3610030        B5   G6350          S
# Chelsea and Clinton        36     10011  3610011        B5   G6350          S
# East Harlem                36     10029  3610029        B5   G6350          S
# Gramercy Park              36     10017  3610017        B5   G6350          S
#
#                       ALAND10  AWATER10   INTPTLAT10    INTPTLON10 PARTFLG10  \
# zone
# Brooklyn             19547849   2143727  +40.6050798  -073.9117206         N
# Central Harlem         722465         0  +40.8182666  -073.9428564         N
# Chelsea and Clinton   1705243         0  +40.7420017  -074.0005940         N
# East Harlem           2136945         0  +40.7916981  -073.9438757         N
# Gramercy Park          829152         0  +40.7523468  -073.9724169         N
#
#                        zip
# zone
# Brooklyn             11234
# Central Harlem       10030
# Chelsea and Clinton  10011
# East Harlem          10029
# Gramercy Park        10017

# %% [markdown]
# ## Scalable Method

# %%
# Create dictionary of dictionaries for each zone that returns the "exterior" and "buffered exterior" 20 coordinates
zone_names = pd.unique(zip_df['zone'])
keys = range(len(zone_names))
r = {}
for x in keys:
    r[x] = {} #creates sub-dictionary
    r[x]['Name'] = zone_names[x] 
    r[x]['Group'] = zones.loc[[zone_names[x]], 'geometry']
    if r[x]['Group'].geom_type[0] == 'MultiPolygon': #second [0] filters to the Polygon level
        r[x]['Exterior'] = int(math.ceil(len(r[x]['Group'][0][0].exterior.coords)/20)) #returns every nth number to use below
        r[x]['Exterior_Coords'] = r[x]['Group'][0][0].exterior.coords[0::r[x]['Exterior']] #returns every nth coordinate (20 total)
        r[x]['Buffer'] = int(math.ceil(len(r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords)/20))
        r[x]['Buffer_Coords'] = r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords[0::r[x]['Buffer']]    
    else: 
        r[x]['Exterior'] = int(math.ceil(len(r[x]['Group'][0].exterior.coords)/20)) 
        r[x]['Exterior_Coords'] = r[x]['Group'][0].exterior.coords[0::r[x]['Exterior']]
        r[x]['Buffer'] = int(math.ceil(len(r[x]['Group'][0].buffer(0.01,16, join_style = 2).exterior.coords)/20))
        r[x]['Buffer_Coords'] = r[x]['Group'][0].buffer(0.01,16, join_style = 2).exterior.coords[0::r[x]['Buffer']] 
r
# Out:
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:10: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior'] = int(math.ceil(len(r[x]['Group'][0][0].exterior.coords)/20)) #returns every nth number to use below
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:11: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior_Coords'] = r[x]['Group'][0][0].exterior.coords[0::r[x]['Exterior']] #returns every nth coordinate (20 total)
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:12: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer'] = int(math.ceil(len(r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords)/20))
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:13: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer_Coords'] = r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords[0::r[x]['Buffer']]
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:10: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior'] = int(math.ceil(len(r[x]['Group'][0][0].exterior.coords)/20)) #returns every nth number to use below
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:11: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior_Coords'] = r[x]['Group'][0][0].exterior.coords[0::r[x]['Exterior']] #returns every nth coordinate (20 total)
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:12: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer'] = int(math.ceil(len(r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords)/20))
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:13: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer_Coords'] = r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords[0::r[x]['Buffer']]
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:10: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior'] = int(math.ceil(len(r[x]['Group'][0][0].exterior.coords)/20)) #returns every nth number to use below
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:11: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior_Coords'] = r[x]['Group'][0][0].exterior.coords[0::r[x]['Exterior']] #returns every nth coordinate (20 total)
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:12: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer'] = int(math.ceil(len(r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords)/20))
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:13: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer_Coords'] = r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords[0::r[x]['Buffer']]
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:10: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior'] = int(math.ceil(len(r[x]['Group'][0][0].exterior.coords)/20)) #returns every nth number to use below
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:11: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior_Coords'] = r[x]['Group'][0][0].exterior.coords[0::r[x]['Exterior']] #returns every nth coordinate (20 total)
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:12: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer'] = int(math.ceil(len(r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords)/20))
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:13: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer_Coords'] = r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords[0::r[x]['Buffer']]
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:10: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior'] = int(math.ceil(len(r[x]['Group'][0][0].exterior.coords)/20)) #returns every nth number to use below
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:11: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior_Coords'] = r[x]['Group'][0][0].exterior.coords[0::r[x]['Exterior']] #returns every nth coordinate (20 total)
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:12: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer'] = int(math.ceil(len(r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords)/20))
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:13: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer_Coords'] = r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords[0::r[x]['Buffer']]
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:10: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior'] = int(math.ceil(len(r[x]['Group'][0][0].exterior.coords)/20)) #returns every nth number to use below
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:11: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior_Coords'] = r[x]['Group'][0][0].exterior.coords[0::r[x]['Exterior']] #returns every nth coordinate (20 total)
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:12: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer'] = int(math.ceil(len(r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords)/20))
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:13: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer_Coords'] = r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords[0::r[x]['Buffer']]
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:10: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior'] = int(math.ceil(len(r[x]['Group'][0][0].exterior.coords)/20)) #returns every nth number to use below
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:11: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior_Coords'] = r[x]['Group'][0][0].exterior.coords[0::r[x]['Exterior']] #returns every nth coordinate (20 total)
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:12: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer'] = int(math.ceil(len(r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords)/20))
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:13: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer_Coords'] = r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords[0::r[x]['Buffer']]
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:10: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior'] = int(math.ceil(len(r[x]['Group'][0][0].exterior.coords)/20)) #returns every nth number to use below
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:11: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Exterior_Coords'] = r[x]['Group'][0][0].exterior.coords[0::r[x]['Exterior']] #returns every nth coordinate (20 total)
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:12: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer'] = int(math.ceil(len(r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords)/20))
# /var/folders/4_/q_7tb_w52611r6nz11nb05qm0000gp/T/ipykernel_2922/870032046.py:13: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   r[x]['Buffer_Coords'] = r[x]['Group'][0][0].buffer(0.01,16, join_style = 2).exterior.coords[0::r[x]['Buffer']]
# {0: {'Name': 'East Harlem',
#   'Group': zone
#   East Harlem    MULTIPOLYGON (((-73.92869 40.78118, -73.93149 ...
#   Name: geometry, dtype: geometry,
#   'Exterior': 3,
#   'Exterior_Coords': [(-73.928686, 40.781184),
#    (-73.935929, 40.783807),
#    (-73.93551, 40.7859),
#    (-73.932714, 40.78929),
#    (-73.931404, 40.791146),
#    (-73.925754, 40.791303),
#    (-73.926622, 40.79163),
#    (-73.92654, 40.79452),
#    (-73.926879, 40.799987),
#    (-73.918837, 40.798814),
#    (-73.914684, 40.795799),
#    (-73.915592, 40.791998),
#    (-73.923803, 40.783779),
#    (-73.927829, 40.781075)],
#   'Buffer': 2,
#   'Buffer_Coords': [(-73.94648356990037, 40.783453230873405),
#    (-73.94120155505074, 40.79465514352185),
#    (-73.94017105868987, 40.79599229449111),
#    (-73.93708362837576, 40.80014686790213),
#    (-73.9301053295897, 40.811942081274125),
#    (-73.91304868398235, 40.80698687384361),
#    (-73.90959455847604, 40.80487830831102),
#    (-73.90395432040015, 40.79403505948594),
#    (-73.90862632259017, 40.78481513758067),
#    (-73.91455210032179, 40.779181948219744),
#    (-73.92079038752489, 40.77395573647828),
#    (-73.93154662515164, 40.771467277529865),
#    (-73.94062082052827, 40.77403330487078),
#    (-73.94648356990037, 40.783453230873405)]},
#  1: {'Name': 'Gramercy Park',
#   'Group': zone
#   Gramercy Park    POLYGON ((-73.98451 40.73696, -73.98445 40.737...
#   Name: geometry, dtype: geometry,
#   'Exterior': 8,
#   'Exterior_Coords': [(-73.984508, 40.736962),
#    (-73.986854, 40.738714),
#    (-73.993739, 40.741617),
#    (-73.990968, 40.745421),
#    (-73.986393, 40.745921),
#    (-73.982724, 40.750959),
#    (-73.979937, 40.754783),
#    (-73.976289, 40.759787),
#    (-73.971411, 40.763588),
#    (-73.963884, 40.761233),
#    (-73.962141, 40.760492),
#    (-73.958599, 40.758133),
#    (-73.9629, 40.753258),
#    (-73.969163, 40.746048),
#    (-73.972421, 40.74009),
#    (-73.972577, 40.735166),
#    (-73.974001, 40.734896),
#    (-74.00130620319526, 40.696961308252),
#    (-74.00564624366538, 40.70626430499807),
#    (-74.01284383895398, 40.71014385567794),
#    (-74.00743955713031, 40.71744592018844),
#    (-74.00461657532229, 40.72140162500425),
#    (-74.00912497170606, 40.72457646255574)]},
#  11: {'Name': 'Lower Westchester',
#   'Group': zone
#   Lower Westchester    MULTIPOLYGON (((-73.83970 40.89738, -73.83972 ...
#   Name: geometry, dtype: geometry,
#   'Exterior': 281,
#   'Exterior_Coords': [(-73.839696, 40.897385),
#    (-73.910299, 40.915855),
#    (-73.892675, 40.962174),
#    (-73.873688, 41.041283),
#    (-73.819313, 41.042826),
#    (-73.75768, 41.038472),
#    (-73.692554, 41.015002),
#    (-73.678051, 41.039808),
#    (-73.667712, 40.966236),
#    (-73.682958, 40.94966),
#    (-73.691549, 40.954421),
#    (-73.701885, 40.949333),
#    (-73.722649, 40.936853),
#    (-73.734111, 40.928475),
#    (-73.745036, 40.922665),
#    (-73.760922, 40.907728),
#    (-73.76365, 40.916653),
#    (-73.767675, 40.908228),
#    (-73.776725, 40.889758),
#    (-73.78427, 40.889149)],
#   'Buffer': 29,
#   'Buffer_Coords': [(-73.92139258893643, 40.91493239192996),
#    (-73.90128979242257, 40.96878707077279),
#    (-73.89136287838762, 41.01161014121675),
#    (-73.88256278880579, 41.04785196922533),
#    (-73.8246914232343, 41.0582666857676),
#    (-73.78396040414276, 41.052406388209036),
#    (-73.73497636649822, 41.03645909873139),
#    (-73.70164231615104, 41.03982307168141),
#    (-73.68521825663613, 41.064156947448105),
#    (-73.67063632705012, 41.046556802115894),
#    (-73.65757518813736, 41.03012005045383),
#    (-73.64899306634267, 41.000563941175216),
#    (-73.65201048330287, 40.96302932670994),
#    (-73.71261188142483, 40.91869988793935),
#    (-73.75100245407009, 40.90244014774245),
#    (-73.77650812246735, 40.87933235731488),
#    (-73.8111260821823, 40.87774424824225),
#    (-73.83871931200335, 40.883811989263464),
#    (-73.87353592803329, 40.8942274381497),
#    (-73.89581577805306, 40.90052312083452)]},
#  12: {'Name': 'Upper Westchester',
#   'Group': zone
#   Upper Westchester    MULTIPOLYGON (((-73.87082 41.04696, -73.87068 ...
#   Name: geometry, dtype: geometry,
#   'Exterior': 437,
#   'Exterior_Coords': [(-73.87082, 41.046962),
#    (-73.868307, 41.119449),
#    (-73.876479, 41.176577),
#    (-73.897809, 41.207095),
#    (-73.952638, 41.243641),
#    (-73.942397, 41.272536),
#    (-73.95013, 41.296362),
#    (-73.955141, 41.367163),
#    (-73.962671, 41.417514),
#    (-73.985027, 41.488049),
#    (-73.960472, 41.524314),
#    (-73.746009, 41.628857),
#    (-73.723281, 41.604401),
#    (-73.744098, 41.547342),
#    (-73.62159, 41.484302),
#    (-73.657381, 41.369717),
#    (-73.687881, 41.307744),
#    (-73.756815, 41.28664),
#    (-73.770626, 41.221648),
#    (-73.756103, 41.124003)],
#   'Buffer': 68,
#   'Buffer_Coords': [(-73.99264014889987, 41.44786909528936),
#    (-73.998659, 40.671705),
#    (-74.005846, 40.687747),
#    (-73.987546, 40.704747),
#    (-73.971104, 40.70346),
#    (-73.961611, 40.724951),
#    (-73.927205, 40.725252),
#    (-73.906748, 40.697077),
#    (-73.891071, 40.684174),
#    (-73.860389, 40.671269),
#    (-73.866606, 40.649263),
#    (-73.890429, 40.62221),
#    (-73.936691, 40.575447),
#    (-73.952325, 40.574134)],
#   'Buffer': 13,
#   'Buffer_Coords': [(-74.0522524997591, 40.621355921833434),
#    (-74.04823863171474, 40.64512847523915),
#    (-74.02443684991667, 40.688280049818104),
#    (-74.0111175113526, 40.69636455469661),
#    (-74.00661174425215, 40.70457551446154),
#    (-73.98666504274557, 40.714800757854476),
#    (-73.97358324309472, 40.72500335249164),
#    (-73.97264722153814, 40.73570028203618),
#    (-73.93601519072344, 40.74373912614244),
#    (-73.91368766634815, 40.720750046969314),
#    (-73.88812752931167, 40.69714997054688),
#    (-73.85019227638324, 40.68273722738436),
#    (-73.84935491817633, 40.636631585851575),
#    (-73.87404323174063, 40.60469634365775),
#    (-73.92673885063066, 40.566188023136526),
#    (-73.96580388550588, 40.562372094665164),
#    (-73.98723526114513, 40.560396804141156),
#    (-74.01674591659582, 40.56518973703137),
#    (-74.0163051324525, 40.59187873549898),
#    (-74.04774060185153, 40.607679089385684)]}}

# %%
# create Name/Coord dictionaries
exterior = {r[x]['Name']: r[x]['Exterior_Coords'] for x in r}
buffer = {r[x]['Name']: r[x]['Buffer_Coords'] for x in r}

# %%
# Create lists to use for developing geopandas dataframes
ex_n = [r[x]['Name'] for x in r]
ex_c = [Polygon(r[x]['Exterior_Coords']) for x in r]
bf_c = [Polygon(r[x]['Buffer_Coords']) for x in r]

# %%
# Create GeoPandas Dataframes and send to file for plotting
d = {'Zone': ex_n, 'geometry': ex_c}
e = {'Zone': ex_n, 'geometry': bf_c}
ex_gdf = geopandas.GeoDataFrame(d, crs="EPSG:4326")
bf_gdf = geopandas.GeoDataFrame(e, crs="EPSG:4326")
ex_gdf.to_file("exterior.geojson", driver="GeoJSON")
bf_gdf.to_file("buffer.geojson", driver="GeoJSON")
bf_gdf
# Out:
# /Users/paul.nisenson/.conda/envs/gis_project/lib/python3.8/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /Users/paul.nisenson/.conda/envs/gis_project/lib/python3.8/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
#                           Zone  \
# 0                  East Harlem
# 1                Gramercy Park
# 2              Upper East Side
# 3               Central Harlem
# 4          Chelsea and Clinton
# 5              Upper West Side
# 6           Washington Heights
# 7                       Inwood
# 8   Greenwich Village and Soho
# 9              Lower Manhattan
# 10             Lower East Side
# 11           Lower Westchester
# 12           Upper Westchester
# 13                      Queens
# 14                    Brooklyn
#
#                                              geometry
# 0   POLYGON ((-73.94648 40.78345, -73.94120 40.794...
# 1   POLYGON ((-74.00002 40.73263, -74.00138 40.748...
# 2   POLYGON ((-73.97484 40.75500, -73.97925 40.772...
# 3   POLYGON ((-73.97987 40.80303, -73.97764 40.818...
# 4   POLYGON ((-74.02551 40.74852, -74.02788 40.758...
# 5   POLYGON ((-74.00211 40.76763, -73.99437 40.790...
# 6   POLYGON ((-73.96209 40.81051, -73.98654 40.818...
# 7   POLYGON ((-73.94286 40.82631, -73.93631 40.851...
# 8   POLYGON ((-74.02783 40.71599, -74.02444 40.732...
# 9   POLYGON ((-74.00319 40.69745, -73.98497 40.691...
# 10  POLYGON ((-74.00912 40.72458, -74.00121 40.744...
# 11  POLYGON ((-73.92139 40.91493, -73.90129 40.968...
# 12  POLYGON ((-73.99264 41.44787, -73.99244 41.533...
# 13  POLYGON ((-73.94868 40.74022, -73.92440 40.757...
# 14  POLYGON ((-74.05225 40.62136, -74.04824 40.645...

# %%
# create list in format for NYP
# format is [{latitude: "37.472", longitude: "-122.248"},{latitude: "37.525", longitude: "-122.163"},{latitude: "37.399", longitude: "-122.059"},{latitude: "37.472", longitude: "-122.248"}]
# i.e. list of dictionaries


def coord_list(coord_type):
    tester = []
    string = ''
    for y in coord_type:
        for x in coord_type[y]:
            string += (f'{{latitude: "{x[1]}", longitude: "{x[0]}"}},')
        tester.append([f'{y} : {string[0:-1]}'])
        string = ''
    return tester

pd.DataFrame({"Exterior": coord_list(exterior), "Buffer":coord_list(buffer)}).to_csv('Coordinates.csv')
pd.DataFrame({"Exterior": coord_list(exterior), "Buffer":coord_list(buffer)})
# Out:
#                                              Exterior  \
# 0   [East Harlem : {latitude: "40.781184", longitu...
# 1   [Gramercy Park : {latitude: "40.736962", longi...
# 2   [Upper East Side : {latitude: "40.758528", lon...
# 3   [Central Harlem : {latitude: "40.797478", long...
# 4   [Chelsea and Clinton : {latitude: "40.740291",...
# 5   [Upper West Side : {latitude: "40.778168", lon...
# 6   [Washington Heights : {latitude: "40.829724", ...
# 7   [Inwood : {latitude: "40.807955", longitude: "...
# 8   [Greenwich Village and Soho : {latitude: "40.7...
# 9   [Lower Manhattan : {latitude: "40.687934", lon...
# 10  [Lower East Side : {latitude: "40.712799", lon...
# 11  [Lower Westchester : {latitude: "40.897385", l...
# 12  [Upper Westchester : {latitude: "41.046962", l...
# 13  [Queens : {latitude: "40.688412", longitude: "...
# 14  [Brooklyn : {latitude: "40.574012", longitude:...
#
#                                                Buffer
# 0   [East Harlem : {latitude: "40.783453230873405"...
# 1   [Gramercy Park : {latitude: "40.73263485554648...
# 2   [Upper East Side : {latitude: "40.755001660557...
# 3   [Central Harlem : {latitude: "40.8030307901594...
# 4   [Chelsea and Clinton : {latitude: "40.74851817...
# 5   [Upper West Side : {latitude: "40.767629344527...
# 6   [Washington Heights : {latitude: "40.810506947...
# 7   [Inwood : {latitude: "40.82630899124321", long...
# 8   [Greenwich Village and Soho : {latitude: "40.7...
# 9   [Lower Manhattan : {latitude: "40.697450143576...
# 10  [Lower East Side : {latitude: "40.724576462555...
# 11  [Lower Westchester : {latitude: "40.9149323919...
# 12  [Upper Westchester : {latitude: "41.4478690952...
# 13  [Queens : {latitude: "40.74021812335903", long...
# 14  [Brooklyn : {latitude: "40.621355921833434", l...
